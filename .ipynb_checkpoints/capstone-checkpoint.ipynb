# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statistics 
import sklearn.metrics as metrics
import keras

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,chi2

from sklearn.linear_model          import LogisticRegression, SGDClassifier, PassiveAggressiveClassifier
from sklearn.neighbors             import KNeighborsClassifier
from sklearn.svm                   import SVC
from sklearn.tree                  import DecisionTreeClassifier
from sklearn.ensemble              import RandomForestClassifier
from sklearn.ensemble              import GradientBoostingClassifier, AdaBoostClassifier

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from keras.utils import to_categorical
from keras.layers import Dense, Flatten
from keras.models import Sequential
from keras.callbacks import History 
from keras.utils import plot_model
from keras.optimizers import SGD


import seaborn as sns
# %matplotlib inline


import warnings
warnings.filterwarnings("ignore")

season_stats = pd.read_csv('nba-players-stats/Seasons_Stats.csv', index_col=0)

# %%
## Data Filter / Data Clean / Hall of Fame column

## Players past 1980 and minimum number of games > 30 are used for evaluation
season_stats_filtered = season_stats.copy()
season_stats_filtered = season_stats.query('Year >= 1980')
season_stats_filtered = season_stats_filtered.query('G >= 30')

## Removed columns with no predictive power
season_stats_filtered.drop(['GS','blanl','blank2','blank2','Age', 'Tm'], axis=1, inplace=True)

## All the null values are handled - these values are null because there is 0 sample for the percentiles - thus 0.
null_data = season_stats_filtered[season_stats_filtered.isnull().any(axis=1)]
season_stats_filtered.fillna(0, inplace=True)

##Make column where each players are hall of famer or not##
hof_container = season_stats_filtered.copy()
hof_container['Player'] = hof_container['Player'].str.replace("*", "_hof")
hof_container = hof_container[hof_container['Player'].str.contains("_hof")]['Player'].str.replace("_hof", "*").unique()
season_stats_filtered['isHoF'] = ''
season_stats_filtered['isHoF'] = np.where(season_stats_filtered['Player'].isin(hof_container), 1,0)
season_stats_filtered['Player'] = season_stats_filtered['Player'].str.replace("*", "")

## Remove correlating features
independent_features = ['Player', 'Pos', 'G','MP', '2P', '2P%', '3P', '3P%', 'FT', 'FT%', 'USG%', 'ORB', 'DRB', 'AST', 'AST%', 'STL', 'STL%', 'BLK', 'BLK%', 'TOV', 'PTS', 'isHoF']
season_stats_filtered = season_stats_filtered[independent_features]

## Divide each countable features by G and remove G
countable_columns = ['MP', '2P','3P', 'FT','ORB','DRB','AST','STL','BLK','TOV','PTS']
season_stats_filtered[countable_columns]  = season_stats_filtered[countable_columns] .div(season_stats_filtered['G'].values,axis=0)

season_stats_filtered.rename(columns={'MP':'MP/G','2P':'2P/G','3P':'3P/G','FT':'FT/G'
                                     ,'ORB':'ORB/G','DRB':'DRB/G','AST':'AST/G','STL':'STL/G'
                                     ,'BLK':'BLK/G','TOV':'TOV/G','PTS':'PTS/G'}, inplace=True)
season_stats_filtered.drop(['G'], axis=1, inplace=True)

season_stats_filtered = season_stats_filtered.reset_index(drop=True)

## Split each players by positions
# pg_df = season_stats_filtered[season_stats_filtered.Pos=='PG'].groupby(['Player']).mean().reset_index().round(2)
# sg_df = season_stats_filtered[season_stats_filtered.Pos=='SG'].groupby(['Player']).mean().reset_index().round(2)
# sf_df = season_stats_filtered[season_stats_filtered.Pos=='SF'].groupby(['Player']).mean().reset_index().round(2)
# pf_df = season_stats_filtered[season_stats_filtered.Pos=='PF'].groupby(['Player']).mean().reset_index().round(2)
# c_df = season_stats_filtered[season_stats_filtered.Pos=='C'].groupby(['Player']).mean().reset_index().round(2)

# pg_df = season_stats_filtered[season_stats_filtered.Pos=='PG'].drop(['Pos'], axis=1)
# sg_df = season_stats_filtered[season_stats_filtered.Pos=='SG'].drop(['Pos'], axis=1)
# sf_df = season_stats_filtered[season_stats_filtered.Pos=='SF'].drop(['Pos'], axis=1)
# pf_df = season_stats_filtered[season_stats_filtered.Pos=='PF'].drop(['Pos'], axis=1)
# c_df = season_stats_filtered[season_stats_filtered.Pos=='C'].drop(['Pos'], axis=1)

df_all_player = season_stats_filtered.drop(['Pos'], axis=1)

positional_dfs = [df_all_player]

# %%
## Helper Functions ##

def split_to_train_and_test_sets(df):

    X = df.drop(['Player','isHoF'],axis=1)
    y = df.isHoF
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25, random_state=0, stratify =y)
    return X, y, X_train,X_test,y_train,y_test

def generate_plot_df(X_train, y_train):
    df_plot = pd.DataFrame(data=X_train, columns=X_train.columns)
    df_plot['isHoF'] = y_train
    df_plot_hof  = df_plot[df_plot['isHoF'] == 1]
    df_plot_nhof  = df_plot[df_plot['isHoF'] == 0]
    return df_plot, df_plot_hof, df_plot_nhof

def generate_plt(df_plot, df_plot_hof, df_plot_nhof):
    plt.figure(figsize=(15, 15))
    for i, feature in enumerate(df_plot.columns[:-1]):
        plt.subplot(6, 4, i+1)
        sns.violinplot(x="isHoF", y=feature, data=df_plot, palette={0: "#ffcc5d", 1: "#5d80ff"})
        plt.xlabel('Hall of Fame Status')
        plt.ylabel(feature)
        plt.grid(True)
        plt.tight_layout()
    plt.figure(figsize=(15, 15))
    for i, feature in enumerate(df_plot.columns[:-1]):
        plt.subplot(6, 4, i+1)
        sns.distplot(df_plot_hof[feature], bins=10, color="#5d80ff",
                      kde_kws={"label": "HOF"},
                      hist_kws={"linewidth": 1,
                                "alpha": 0.5,"color": "#5d80ff"})
        sns.distplot(df_plot_nhof[feature], bins=10, color="#ffcc5d",
                      kde_kws={"label": "Non-HOF"},
                      hist_kws={"linewidth": 1,
                                "alpha": 0.5,"color": "#ffcc5d"})
        plt.xlabel(feature)
        plt.ylabel('Probability Density')
        plt.grid(True)
        plt.tight_layout()

        
def feature_elimination(X,y):
    cols = list(X.columns)
    pmax = 1
    elim_feat_from_p_val_backward_elim = []
    while (len(cols)>0):
        p= []
        X_1 = X[cols]
        X_1 = sm.add_constant(X_1)
        model = sm.OLS(y,X_1).fit()
        p = pd.Series(model.pvalues.values[1:],index = cols)      
        pmax = max(p)
        feature_with_p_max = p.idxmax()

        if(pmax>0.05):
            cols.remove(feature_with_p_max)
            elim_feat_from_p_val_backward_elim.append(feature_with_p_max)
        else:
            break
    elim_feat_from_corr = df_plot.corr()['isHoF'].abs().sort_values()
    elim_feat_from_corr = list(elim_feat_from_corr[elim_feat_from_corr < 0.10].keys())
    elim_fields = list(set(elim_feat_from_p_val_backward_elim).intersection(set(elim_feat_from_corr)))
    return elim_fields

removed_features = []
for df in positional_dfs:
    
    X,y,X_train,X_test,y_train,y_test = split_to_train_and_test_sets(df)
    
    print(X_test)
    df_plot, df_plot_hof, df_plot_nhof = generate_plot_df(X_train, y_train)
    generate_plt(df_plot, df_plot_hof, df_plot_nhof)
    elim_fields = feature_elimination(X,y)
    removed_features.append(elim_fields)
    df.drop(elim_fields, axis=1, inplace=True)

removed_feature_summary_df = pd.DataFrame(data=removed_features)
removed_feature_summary_df.rename(index={0:'PG',1:'SG', 2:'SF', 3:'PF', 4:'C'}, inplace=True)

print('Removed Feature Summary')
display(removed_feature_summary_df)
# Out:
#             MP/G      2P/G    2P%      FT/G  USG%     ORB/G     DRB/G  \
# 8659   15.981481  1.833333  0.518  1.259259  14.4  2.018519  2.740741
# 7791   16.896104  3.428571  0.518  1.584416  23.0  1.805195  2.649351
# 2493   17.800000  2.933333  0.477  1.511111  19.4  0.333333  0.666667
# 1171   18.716981  3.320755  0.452  0.981132  18.5  0.415094  0.773585
# 4001   17.450000  2.325000  0.504  1.300000  14.7  1.650000  2.400000
# ...          ...       ...    ...       ...   ...       ...       ...
# 7692   35.987500  5.625000  0.507  4.050000  19.7  1.875000  4.550000
# 9873   12.135593  1.457627  0.432  0.983051  20.9  0.745763  1.203390
# 2620   22.215190  2.240506  0.437  0.835443  13.6  0.670886  1.417722
# 12851  18.157895  1.508772  0.422  0.947368  17.1  0.894737  3.385965
# 12957  11.820513  1.461538  0.582  0.615385  15.4  0.307692  1.000000
#
#           AST/G  AST%     STL/G     BLK/G  BLK%     TOV/G      PTS/G
# 8659   0.500000   4.9  0.759259  0.703704   3.3  0.481481   4.925926
# 7791   0.532468   5.7  0.545455  0.181818   0.8  0.805195   8.441558
# 2493   1.688889  12.7  0.666667  0.111111   0.4  0.866667   7.711111
# 1171   0.943396   6.5  0.452830  0.396226   1.1  0.754717   7.792453
# 4001   0.512500   4.1  0.462500  0.287500   1.0  0.812500   5.950000
# ...         ...   ...       ...       ...   ...       ...        ...
# 7692   2.512500  12.1  1.000000  0.550000   1.1  1.950000  15.525000
# 9873   0.711864   9.5  0.254237  0.491525   3.4  0.881356   4.711864
# 2620   7.848101  46.2  1.405063  0.088608   0.2  1.569620   5.354430
# 12851  1.912281  16.3  0.385965  0.473684   2.1  1.017544   5.964912
# 12957  2.230769  28.3  0.410256  0.000000   0.0  0.948718   3.692308
#
# [3382 rows x 14 columns]
#             MP/G      2P/G    2P%      FT/G  USG%     ORB/G     DRB/G  \
# 7199   39.705128  3.961538  0.451  2.538462  18.2  2.307692  3.051282
# 9039   15.788732  1.845070  0.533  1.056338  14.0  1.394366  2.535211
# 1762   32.483871  6.290323  0.480  3.129032  23.1  2.967742  6.064516
# 781    19.792683  3.073171  0.482  1.707317  18.7  1.597561  3.609756
# 3045    9.655172  0.724138  0.447  0.551724  10.9  0.689655  1.810345
# ...          ...       ...    ...       ...   ...       ...       ...
# 226    30.431373  6.235294  0.480  2.647059  23.4  0.549020  2.313725
# 839    32.329114  9.139241  0.589  3.518987  24.6  2.113924  5.379747
# 451    22.687500  2.800000  0.490  1.500000  15.7  1.762500  3.462500
# 4395   34.164557  6.025316  0.506  3.063291  20.4  2.784810  5.848101
# 12459  27.960000  4.100000  0.490  1.980000  22.1  0.560000  3.460000
#
#           AST/G  AST%     STL/G     BLK/G  BLK%     TOV/G      PTS/G
# 7199   2.769231  11.9  1.551282  1.038462   1.8  1.987179  14.423077
# 9039   0.197183   2.0  0.281690  0.957746   4.7  0.718310   4.746479
# 1762   1.516129   7.5  0.870968  0.387097   0.7  2.806452  15.709677
# 781    1.780488  11.6  0.560976  0.878049   2.4  1.841463   7.853659
# 3045   0.327586   4.5  0.258621  0.448276   2.8  0.413793   2.000000
# ...         ...   ...       ...       ...   ...       ...        ...
# 226    3.666667  17.8  1.215686  0.294118   0.6  2.372549  15.529412
# 839    2.531646  10.8  0.772152  2.151899   3.5  2.531646  21.797468
# 451    1.687500  10.7  0.475000  0.912500   2.4  2.000000   7.100000
# 4395   2.113924  10.0  0.797468  1.012658   1.9  2.177215  15.379747
# 12459  4.280000  24.5  0.840000  0.100000   0.3  1.820000  12.820000
#
# [10146 rows x 14 columns]
# Removed Feature Summary
# Empty DataFrame
# Columns: []
# Index: [PG]

# %%
models = []

def estimator_dict(name, estimator):
    model = {'name':name, 'estimator':estimator}
    return model

models.append(estimator_dict('K-Nearest Neighbours Classifier', KNeighborsClassifier(n_neighbors=3, weights='uniform')))
models.append(estimator_dict('Logistic Regression Classifier', LogisticRegression(C=0.1)))
models.append(estimator_dict('SVM Classifier', SVC(probability=True)))
models.append(estimator_dict('Stochastic Gradient Descent Classifier', SGDClassifier(loss="log", random_state=50)))
models.append(estimator_dict('Gaussian Naive Bayes Classifier', GaussianNB()))
models.append(estimator_dict('Decision Tree Classifier', DecisionTreeClassifier(max_depth=None, max_features='auto', random_state=50)))
models.append(estimator_dict('Random Forest Classifier', RandomForestClassifier(n_estimators=200, max_depth=None, max_features='auto', random_state=50)))
models.append(estimator_dict('Adaptive Boosted Decision Tree Classifier', AdaBoostClassifier(n_estimators=200, learning_rate=0.1, random_state=50)))
models.append(estimator_dict('Gradient Boosted Decision Tree Classifier', GradientBoostingClassifier(n_estimators=200, max_depth=3, learning_rate=0.1, random_state=50)))

# %%
## ---- END OF PART 1 --
## Investigate failure caes whether false positive or false negative and explain
## Implement the theory - re-design model
## re-run model

## Dataset of "test test" --> see result
## Try to find trend for false +ves/ False -ves
from sklearn.metrics import roc_curve, roc_auc_score

df_summary_lists = []
for df in positional_dfs:

    X = df.drop(['Player','isHoF'],axis=1)
    y = df.isHoF

    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25, random_state=1, stratify =y)
    
    X_scaler = StandardScaler(with_mean=True, with_std=True) 
    X_train_scaled = X_scaler.fit_transform(X_train) 
    X_test_scaled  = X_scaler.transform(X_test)

    model_vals = []
    

    for model_dict in models:
        name = model_dict['name']
        estimator = model_dict['estimator']

        print("doing estimation on...", model_dict['name'])

        model = estimator.fit(X_train_scaled, y_train)
        y_pred = model.predict(X_test_scaled)

        acc_score = accuracy_score(y_pred, y_test)
        report = classification_report(y_pred, y_test)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
        thresholds = np.arange(0.05, 1, 0.05)
        precisions = list()
        recalls = list()
        neg_recalls = list()
        f1_list = list()
    
        for threshold in thresholds:
            y_proba = model.predict_proba(X_test_scaled)[:,1]
            y_threshold = np.where(y_proba > threshold, 1, 0)
            precision = precision_score(y_test, y_threshold)
            recall = recall_score(y_test, y_threshold)
            neg_recall = recall_score(1-y_test, 1-y_pred)
            f1 = f1_score(y_test, y_pred)
            precisions.append(precision)
            recalls.append(recall)
            neg_recalls.append(neg_recall)
            f1_list.append(f1)
        
        tprs = np.array(recalls)
        fprs = 1 - np.array(neg_recalls)
        fprs, tprs, thresholds = roc_curve(y_test, y_proba)
        roc_auc = roc_auc_score(y_test, y_proba)

        model_val = {"name": name, "precision_mean" : statistics.mean(precisions), 
                     "recall_mean" : statistics.mean(recalls),
                     "f1_mean":statistics.mean(f1_list), "precision_std": statistics.stdev(precisions),
                     "recall_std" : statistics.stdev(recalls), 'accuracy_score':acc_score, 'TP': tp,
                     "TN": tn, "FP": fp, "FN": fn, 'roc_auc': roc_auc.round(2)
                    }

        model_vals.append(model_val)


    df_sum = pd.DataFrame.from_dict(model_vals)
    df_summary_lists.append(df_sum)
    display(df_sum)
# Out:
# doing estimation on... K-Nearest Neighbours Classifier
# doing estimation on... Logistic Regression Classifier
# doing estimation on... SVM Classifier
# doing estimation on... Stochastic Gradient Descent Classifier
# doing estimation on... Gaussian Naive Bayes Classifier
# doing estimation on... Decision Tree Classifier
# doing estimation on... Random Forest Classifier
# doing estimation on... Adaptive Boosted Decision Tree Classifier
# doing estimation on... Gradient Boosted Decision Tree Classifier
#                                         name  precision_mean  recall_mean  \
# 0            K-Nearest Neighbours Classifier        0.709102     0.507310
# 1             Logistic Regression Classifier        0.713197     0.293129
# 2                             SVM Classifier        0.801624     0.380117
# 3     Stochastic Gradient Descent Classifier        0.540241     0.410819
# 4            Gaussian Naive Bayes Classifier        0.186029     0.704678
# 5                   Decision Tree Classifier        0.407407     0.458333
# 6                   Random Forest Classifier        0.760500     0.361477
# 7  Adaptive Boosted Decision Tree Classifier        0.117906     0.477339
# 8  Gradient Boosted Decision Tree Classifier        0.706685     0.354532
#
#     f1_mean  precision_std  recall_std  accuracy_score   TP    TN   FP   FN  \
# 0  0.616667       0.222273    0.150347        0.972797   74  3216   22   70
# 1  0.378947       0.275091    0.216464        0.965109   36  3228   10  108
# 2  0.460733       0.121043    0.075749        0.969545   44  3235    3  100
# 3  0.441767       0.210819    0.180826        0.958900   55  3188   50   89
# 4  0.294798       0.019083    0.028196        0.855707  102  2792  446   42
# 5  0.431373       0.000000    0.000000        0.948551   66  3142   96   78
# 6  0.469388       0.266465    0.219474        0.969249   46  3232    6   98
# 7  0.352941       0.274164    0.494026        0.964222   33  3228   10  111
# 8  0.488038       0.229722    0.140795        0.968362   51  3224   14   93
#
#    roc_auc
# 0     0.83
# 1     0.89
# 2     0.84
# 3     0.88
# 4     0.88
# 5     0.71
# 6     0.91
# 7     0.88
# 8     0.89

# %% [markdown]
# <h3> Findings based on Model Evaluation </h3>
#
# - Gaussian Naive Bayes Classifier is too loose ( low precision and very high recall )
# - Decision Tree Classifier has low roc_auc along with low precision/recall average
# - Adaptive Boosted Decision Tree Classifier has low precision/recall average
#
# <h3> Response </h3>
#
# - Removed these three classifiers from the list of models being used

# %%
remove_index = [4,5,7]
models = [i for j, i in enumerate(models) if j not in remove_index]

# %%
display(models)
# Out:
# [{'name': 'K-Nearest Neighbours Classifier',
#   'estimator': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                        metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                        weights='uniform')},
#  {'name': 'Logistic Regression Classifier',
#   'estimator': LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#                      intercept_scaling=1, l1_ratio=None, max_iter=100,
#                      multi_class='warn', n_jobs=None, penalty='l2',
#                      random_state=None, solver='warn', tol=0.0001, verbose=0,
#                      warm_start=False)},
#  {'name': 'SVM Classifier',
#   'estimator': SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#       decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#       kernel='rbf', max_iter=-1, probability=True, random_state=None,
#       shrinking=True, tol=0.001, verbose=False)},
#  {'name': 'Stochastic Gradient Descent Classifier',
#   'estimator': SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#                 early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#                 l1_ratio=0.15, learning_rate='optimal', loss='log', max_iter=1000,
#                 n_iter_no_change=5, n_jobs=None, penalty='l2', power_t=0.5,
#                 random_state=50, shuffle=True, tol=0.001, validation_fraction=0.1,
#                 verbose=0, warm_start=False)},
#  {'name': 'Random Forest Classifier',
#   'estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                          max_depth=None, max_features='auto', max_leaf_nodes=None,
#                          min_impurity_decrease=0.0, min_impurity_split=None,
#                          min_samples_leaf=1, min_samples_split=2,
#                          min_weight_fraction_leaf=0.0, n_estimators=200,
#                          n_jobs=None, oob_score=False, random_state=50, verbose=0,
#                          warm_start=False)},
#  {'name': 'Gradient Boosted Decision Tree Classifier',
#   'estimator': GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                              learning_rate=0.1, loss='deviance', max_depth=3,
#                              max_features=None, max_leaf_nodes=None,
#                              min_impurity_decrease=0.0, min_impurity_split=None,
#                              min_samples_leaf=1, min_samples_split=2,
#                              min_weight_fraction_leaf=0.0, n_estimators=200,
#                              n_iter_no_change=None, presort='auto',
#                              random_state=50, subsample=1.0, tol=0.0001,
#                              validation_fraction=0.1, verbose=0,
#                              warm_start=False)}]

# %%
TP_list = [] ## Hall of Famer
TN_list = [] ## Non Hall of Famer
FP_list = [] ## Non Hall of Famer being predicted as Hall of Famer
FN_list = [] ## Hall of Famer being predicted as Non Hall of Famer

print(df_all_player.loc[10993]['Player'])
print(X_test)

for model_dict in models:
    print("doing estimation on...", model_dict['name'])
    name = model_dict['name']
    estimator = model_dict['estimator']
    
    model = estimator.fit(X_train_scaled, y_train)
    y_prediction = model.predict(X_test_scaled)
    print("==> Checking which players are Hall of Famer according to {} ...".format(name))  
    y_test_np = y_test.to_numpy()
    
    

    for i in range(len(X_test)):
        player_name = df_all_player.loc[i]['Player']
        if ((y_test_np[i] == 0) and (y_prediction[i] == 0)):   # TN
            print(i, player_name, "1")
            TN_list.append(player_name)
        elif ((y_test_np[i] == 0) and (y_prediction[i] == 1)): # FP
            print(i, player_name, "2")
            FP_list.append(player_name)
        elif ((y_test_np[i] == 1) and (y_prediction[i] == 0)): # FN
            print(i, player_name, "3")
            FN_list.append(player_name)
        else:                                                # TP
            print(i, player_name, "4")
            TP_list.append(player_name)
    print('NEXT')
    print("--> # of     All-Stars predicted to be     All-Stars = {:>3} (TP)".format(len(TP_list)))
    print("--> # of     All-Stars predicted to be non-All-Stars = {:>3} (FN)".format(len(FN_list)))
    print("--> # of non-All-Stars predicted to be     All-Stars = {:>3} (FP)".format(len(FP_list)))
    print("--> # of non-All-Stars predicted to be non-All-Stars = {:>3} (TN)".format(len(TN_list)))
    print("")
    print("--> Deserved All-Stars     : ", end='')
    print(*TP_list, sep=', ')
    print("")
    print("--> Questionable All-Stars : ", end='')
    print(*FN_list, sep=', ')
    print("")
    print("--> Snubbed non-All-Stars  : ", end='')
    print(*FP_list, sep=', ')
# Out:
# Nate Robinson
#             MP/G      2P/G    2P%      FT/G  USG%     ORB/G     DRB/G  \
# 10993  17.872727  1.509091  0.491  0.600000  21.7  0.272727  1.345455
# 1536   25.775000  3.437500  0.454  1.762500  17.1  0.400000  1.650000
# 11145  19.384615  2.400000  0.417  1.015385  21.8  0.323077  1.076923
# 8974   19.588235  2.014706  0.519  1.176471  14.8  2.058824  3.882353
# 8022   23.811594  2.753623  0.404  1.739130  21.2  0.840580  3.014493
# ...          ...       ...    ...       ...   ...       ...       ...
# 8643   30.012500  3.362500  0.540  1.825000  18.0  0.475000  1.875000
# 1867   11.807018  1.561404  0.517  0.929825  17.5  0.456140  0.982456
# 9423   16.950820  1.983607  0.448  1.000000  22.7  0.098361  1.114754
# 3256   36.100000  9.387500  0.504  5.737500  30.4  2.712500  3.800000
# 7779   27.378049  2.012195  0.416  0.475610  14.4  0.487805  2.451220
#
#           AST/G  AST%     STL/G     BLK/G  BLK%     TOV/G      PTS/G
# 10993  1.909091  17.4  0.527273  0.072727   0.3  1.200000   7.054545
# 1536   4.375000  22.6  1.337500  0.100000   0.2  2.087500   8.787500
# 11145  2.046154  17.0  0.676923  0.030769   0.1  1.615385   6.784615
# 8974   1.014706   8.1  0.308824  1.544118   6.0  1.573529   5.205882
# 8022   1.884058  14.0  0.724638  0.275362   0.9  1.478261   8.985507
# ...         ...   ...       ...       ...   ...       ...        ...
# 8643   5.362500  28.8  1.362500  0.187500   0.5  1.837500  12.412500
# 1867   0.964912  11.2  0.561404  0.087719   0.4  0.719298   4.473684
# 9423   1.000000  10.9  0.344262  0.032787   0.2  0.901639   7.721311
# 3256   2.500000  11.8  1.575000  0.587500   1.0  2.175000  26.725000
# 7779   2.975610  15.8  0.878049  0.158537   0.4  1.000000   7.682927
#
# [3382 rows x 14 columns]
# doing estimation on... K-Nearest Neighbours Classifier
# ==> Checking which players are Hall of Famer according to K-Nearest Neighbours Classifier ...
# 0 Kareem Abdul-Jabbar 1
# 1 Tom Abernethy 1
# 2 Alvan Adams 1
# 3 Tiny Archibald 1
# 4 James Bailey 1
# 5 Greg Ballard 1
# 6 Mike Bantom 1
# 7 Rick Barry 1
# 8 Kent Benson 1
# 9 Kent Benson 1
# 10 Del Beshore 1
# 11 Henry Bibby 1
# 12 Larry Bird 3
# 13 Otis Birdsong 1
# 14 Ron Boone 1
# 15 Ron Boone 1
# 16 Tom Boswell 1
# 17 Tom Boswell 1
# 18 Winford Boynes 1
# 19 Dudley Bradley 1
# 20 Mike Bratz 1
# 21 Jim Brewer 1
# 22 Ron Brewer 1
empf, Purvis Short, Mychal Thompson, Richard Anderson, Roy Hinson, Bill Laimbeer, Pace Mannion, Ben McDonald, Alvin Robertson, Ralph Sampson, Otis Thorpe, Pearl Washington, Herb Williams, Ben Coleman, Bill Laimbeer, Sam Perkins, Jim Petersen, Fred Roberts, Otis Smith, Everette Stephens, Eric White, Frank Brickowski, Tony Brown, Brad Daugherty, Craig Ehlo, Kevin McHale, Sam Perkins, Charles Shackleford, Mychal Thompson, Sam Vincent, Bill Wennington, Randy White, Danny Young, Dale Ellis, Ke ...
#
# --> Snubbed non-All-Stars  : Mike Bratz, Robert Reid, Sidney Wicks, Fred Brown, Bryan Warrick, Alton Lister, Jeff Malone, Scott Hastings, Fat Lever, Ben Coleman, Jim Farmer, Dennis Hopson, Charles Barkley, Jerome Lane, Sam Bowie, Randy Breuer, Charles Davis, Jack Haley, Dan Majerle, Tree Rollins, Terry Teagle, Richard Coffey, Sonny Parker, Larry Demic, Mike Bratz, Eddie Jordan, John Paxson, Blair Rasmussen, Tyrone Corbin, Brad Davis, Reggie Lewis, Brad Lohaus, Adrian Dantley, Jim Farmer, Jerome Lane, Adrian Dantley, Sonny Parker, Clifford Ray, Larry Demic, Robert Reid, Mike Bratz, Junior Bridgeman, Jim Brogan, Alex English, George Johnson, Edgar Jones, Eddie Jordan, Fred Brown, Wayne Cooper, Lewis Lloyd, Danny Schayes, Bryan Warrick, Mike Gibson, John Paxson, Mike Holton, Junior Bridgeman, Randy Breuer, Rick Carlisle, Caldwell Jones, Fat Lever, Blair Rasmussen, Tyrone Corbin, Brad Davis, Jim Farmer, Dennis Hopson, Michael Jackson, Reggie Lewis, Larry Nance, Martin Nessley, Otis Smith, Wayne Cooper, Adrian Dantley, Larry Krystkowiak, Jerome Lane, John Shasky, Joe Wolf, John Battle, Joe Barry, Pat Cummings, Jeff Grayer, Brad Lohaus, Pete Myers, Terry Teagle, Kelly Tripucka, Danny Ferry, Adrian Dantley, Robert Reid, Alex English, Fred Brown, Bryan Warrick, Otis Smith, Sonny Parker, Sam Lacey, Alex English, Julius Erving, Fred Brown, Quintin Dailey, Mark Landsberger, Dennis Hopson, Martin Nessley, Dallas Comegys, Orlando Woolridge, Randy Breuer, Pat Cummings, Kelly Tripucka

# %%
df_all_player.query('Player == "Kareem Abdul-Jabbar" ')

# %%
# n_cols = X_train.shape[1]
# y_train_nn = to_categorical(y_train, 2)

# %%
# hist = History()

# model = Sequential()


# model.add(Dense(300, activation='relu', input_dim = n_cols))
# model.add(Dense(300, activation='relu'))
# model.add(Dense(300, activation='relu'))
# model.add(Dense(300, activation='relu'))

# model.add(Dense(2, activation='softmax'))

# model.compile(optimizer='adam', 
#               loss='binary_crossentropy', 
#               metrics=['accuracy'])


# model.fit(X_train_scaled, y_train_nn, epochs = 40, validation_split = .1, callbacks = [hist])

# y_pred =  model.predict(X_test_scaled)
# y_pred = np.round(y_pred[:,1])


# print(metrics.accuracy_score(y_pred,y_test))

# print("## actual y", y_test.sum())
# print("## y_pred", y_pred.sum())
