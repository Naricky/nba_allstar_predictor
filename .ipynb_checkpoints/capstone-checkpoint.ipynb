# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statistics 
import sklearn.metrics as metrics
import glob

from functools   import reduce
from collections import Counter

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,chi2

from sklearn.linear_model          import LogisticRegression, SGDClassifier, PassiveAggressiveClassifier
from sklearn.neighbors             import KNeighborsClassifier
from sklearn.svm                   import SVC
from sklearn.tree                  import DecisionTreeClassifier
from sklearn.ensemble              import RandomForestClassifier,VotingClassifier,GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,plot_confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from imblearn.over_sampling import SMOTE

import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

season_stats = pd.read_csv('nba-players-stats/Seasons_Stats.csv', index_col=0)

# %%
## Data Filter / Data Clean / Hall of Fame column

## Players past 1980 and minimum number of games > 30 are used for evaluation
season_stats_filtered = season_stats.copy()
season_stats_filtered = season_stats.query('Year >= 1980')
season_stats_filtered = season_stats_filtered.query('G >= 30')

## Removed columns with no predictive power
season_stats_filtered.drop(['GS','blanl','blank2','blank2','Age', 'Tm'], axis=1, inplace=True)

## All the null values are handled - these values are null because there is 0 sample for the percentiles - thus 0.
null_data = season_stats_filtered[season_stats_filtered.isnull().any(axis=1)]
season_stats_filtered.fillna(0, inplace=True)

##Make column where each players are hall of famer or not##
hof_container = season_stats_filtered.copy()
hof_container['Player'] = hof_container['Player'].str.replace("*", "_hof")
hof_container = hof_container[hof_container['Player'].str.contains("_hof")]['Player'].str.replace("_hof", "*").unique()
season_stats_filtered['isHoF'] = ''
season_stats_filtered['isHoF'] = np.where(season_stats_filtered['Player'].isin(hof_container), 1,0)
season_stats_filtered['Player'] = season_stats_filtered['Player'].str.replace("*", "")

## Remove correlating features
independent_features = ['Player', 'Pos', 'G','MP', '2P', '2P%', '3P', '3P%', 'FT', 'FT%', 'USG%', 'ORB', 'DRB', 'AST', 'AST%', 'STL', 'STL%', 'BLK', 'BLK%', 'TOV', 'PTS', 'isHoF']
season_stats_filtered = season_stats_filtered[independent_features]

## Divide each countable features by G and remove G
countable_columns = ['MP', '2P','3P', 'FT','ORB','DRB','AST','STL','BLK','TOV','PTS']
season_stats_filtered[countable_columns]  = season_stats_filtered[countable_columns] .div(season_stats_filtered['G'].values,axis=0)

season_stats_filtered.rename(columns={'MP':'MP/G','2P':'2P/G','3P':'3P/G','FT':'FT/G'
                                     ,'ORB':'ORB/G','DRB':'DRB/G','AST':'AST/G','STL':'STL/G'
                                     ,'BLK':'BLK/G','TOV':'TOV/G','PTS':'PTS/G'}, inplace=True)
season_stats_filtered.drop(['G'], axis=1, inplace=True)

season_stats_filtered = season_stats_filtered.groupby('Player').mean()

season_stats_filtered = season_stats_filtered.round(2).reset_index()

season_stats_filtered[['2P%', '3P%', 'FT%']] = season_stats_filtered[['2P%', '3P%', 'FT%']] * 100

# %%
def train_test_splitter(df):
    X = df
    y = df['isHoF']
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25, random_state=10, stratify =y)
    return  X, y,X_train,X_test,y_train,y_test

def generate_plot_df(X_train, y_train):
    
    df_plot = pd.DataFrame(data=X_train[1:], columns=X_train.columns[1:])
    df_plot['isHoF'] = y_train
    df_plot_hof  = df_plot[df_plot['isHoF'] == 1]
    df_plot_nhof  = df_plot[df_plot['isHoF'] == 0]
    return df_plot, df_plot_hof, df_plot_nhof

def generate_plt(plot_1, plot_2, plot_1_label, plot_2_label):
    plt.figure(figsize=(15, 15))
    for i, feature in enumerate(plot_1.columns[1:-1]):
        plt.subplot(5, 5, i+1)
        sns.distplot(plot_1[feature], bins=10, color="#5d80ff",
                      kde_kws={"label": plot_1_label},
                      hist_kws={"linewidth": 1,
                                "alpha": 0.5,"color": "#5d80ff"})
        sns.distplot(plot_2[feature], bins=10, color="#ffcc5d",
                      kde_kws={"label": plot_2_label},
                      hist_kws={"linewidth": 1,
                                "alpha": 0.5,"color": "#ffcc5d"})
        plt.xlabel(feature)
        plt.ylabel('Probability Density')
        plt.grid(True)
        plt.tight_layout()

def flat_and_dup(list_of_lists):
    cleanlist = []
    list_of_lists = [item for sublist in list_of_lists for item in sublist]
    list_of_lists = sorted(set(list_of_lists), key=lambda x:list_of_lists.index(x))
    return list_of_lists

def drop_player_name_and_label(X):
    X = X.drop(['Player', 'isHoF'],axis=1)
    return X

def standard_scale(X_train, X_test):
    X_scaler = StandardScaler(with_mean=True, with_std=True) 
    X_train_scaled = X_scaler.fit_transform(X_train) 
    X_test_scaled  = X_scaler.transform(X_test)
    return X_train_scaled, X_test_scaled

# %%
X,y,X_train,X_test,y_train,y_test = train_test_splitter(season_stats_filtered)

# %%
df_plot, df_plot_hof, df_plot_nhof = generate_plot_df(X_train, y_train)
generate_plt(df_plot_hof, df_plot_nhof, 'hof', 'nhof')

# %%
models = []

def estimator_dict(name, estimator):
    model = {'name':name, 'estimator':estimator}
    return model

models.append(estimator_dict('K-Nearest Neighbours Classifier', KNeighborsClassifier(n_neighbors=3, weights='uniform')))
models.append(estimator_dict('Logistic Regression Classifier', LogisticRegression(C=0.1)))
models.append(estimator_dict('SVM Classifier', SVC(probability=True)))
models.append(estimator_dict('Stochastic Gradient Descent Classifier', SGDClassifier(loss="log", random_state=50)))
models.append(estimator_dict('Gaussian Naive Bayes Classifier', GaussianNB()))
models.append(estimator_dict('Decision Tree Classifier', DecisionTreeClassifier(max_depth=None, max_features='auto', random_state=50)))
models.append(estimator_dict('Random Forest Classifier', RandomForestClassifier(n_estimators=200, max_depth=None, max_features='auto', random_state=50)))
models.append(estimator_dict('Adaptive Boosted Decision Tree Classifier', AdaBoostClassifier(n_estimators=200, learning_rate=0.1, random_state=50)))
models.append(estimator_dict('Gradient Boosted Decision Tree Classifier', GradientBoostingClassifier(n_estimators=200, max_depth=3, learning_rate=0.1, random_state=50)))

# %%
init_X_train = X_train.copy()
init_X_test = X_test.copy()
init_y_train = y_train.copy()
init_y_test = y_test.copy()

# %%
X_train = drop_player_name_and_label(X_train)
X_test = drop_player_name_and_label(X_test)

# %%
Counter(y_train)
# Out:
# Counter({0: 1576, 1: 41})

# %%
X_train_scaled, X_test_scaled = standard_scale(X_train, X_test)

smote = SMOTE(sampling_strategy='minority')
X_train_scaled, y_train = smote.fit_resample(X_train_scaled, y_train)
# X_test, y_test = smote.fit_resample(X_test, y_test)

# %%
Counter(y_train)
# Out:
# Counter({0: 1576, 1: 1576})

# %%
from sklearn.metrics import roc_curve, roc_auc_score

model_vals = []
df_summary_lists = []



plt.figure(figsize=(5, 5))
for model_dict in models:
    
    name = model_dict['name']
    estimator = model_dict['estimator']

    print("doing estimation on...", model_dict['name'])

    model = estimator.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)

    acc_score = accuracy_score(y_pred, y_test)
    report = classification_report(y_pred, y_test)

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    thresholds = np.arange(0.05, 1, 0.05)
    precisions = list()
    recalls = list()
    neg_recalls = list()
    f1_list = list()
    
    disp = plot_confusion_matrix(model, X_test_scaled, y_test,
                                 display_labels=['non-hof', 'hof'],
                                 cmap=plt.cm.Blues,
                                 )
    for threshold in thresholds:
        y_proba = model.predict_proba(X_test_scaled)[:,1]
        y_threshold = np.where(y_proba > threshold, 1, 0)
        precision = precision_score(y_test, y_threshold)
        recall = recall_score(y_test, y_threshold)
        neg_recall = recall_score(1-y_test, 1-y_pred)
        f1 = f1_score(y_test, y_pred)
        precisions.append(precision)
        recalls.append(recall)
        neg_recalls.append(neg_recall)
        f1_list.append(f1)

    tprs = np.array(recalls)
    fprs = 1 - np.array(neg_recalls)
    fprs, tprs, thresholds = roc_curve(y_test, y_proba)
    roc_auc = roc_auc_score(y_test, y_proba)

    model_val = {"name": name, "precision_mean" : statistics.mean(precisions), 
                 "recall_mean" : statistics.mean(recalls),
                 "f1_mean":statistics.mean(f1_list), "precision_std": statistics.stdev(precisions),
                 "recall_std" : statistics.stdev(recalls), 'accuracy_score':acc_score, 'TP': tp,
                 "TN": tn, "FP": fp, "FN": fn, 'roc_auc': roc_auc.round(2)
                }

    model_vals.append(model_val)

df_sum = pd.DataFrame.from_dict(model_vals)
df_summary_lists.append(df_sum)
# Out:
# doing estimation on... K-Nearest Neighbours Classifier
# doing estimation on... Logistic Regression Classifier
# doing estimation on... SVM Classifier
# doing estimation on... Stochastic Gradient Descent Classifier
# doing estimation on... Gaussian Naive Bayes Classifier
# doing estimation on... Decision Tree Classifier
# doing estimation on... Random Forest Classifier
# doing estimation on... Adaptive Boosted Decision Tree Classifier
# doing estimation on... Gradient Boosted Decision Tree Classifier

# %%
display(df_sum)
# Out:
#                                         name  precision_mean  recall_mean  \
# 0            K-Nearest Neighbours Classifier        0.220697     0.571429
# 1             Logistic Regression Classifier        0.178092     0.706767
# 2                             SVM Classifier        0.275331     0.394737
# 3     Stochastic Gradient Descent Classifier        0.217160     0.661654
# 4            Gaussian Naive Bayes Classifier        0.149258     0.838346
# 5                   Decision Tree Classifier        0.185185     0.357143
# 6                   Random Forest Classifier        0.349700     0.436090
# 7  Adaptive Boosted Decision Tree Classifier        0.052279     0.492481
# 8  Gradient Boosted Decision Tree Classifier        0.232871     0.421053
#
#     f1_mean  precision_std  recall_std  accuracy_score  TP   TN  FP  FN  \
# 0  0.280702       0.068702    0.058321        0.923933   8  490  35   6
# 1  0.285714       0.064524    0.152260        0.907236  10  479  46   4
# ...

# %% [markdown]
# <h3> Findings based on Model Evaluation </h3>
#
# - Adaptive Boosted Decision Tree Classifier	has low precision and recall
# - Decision Tree Classifier has low roc_auc
# - Gaussian Naive Bayes Classifier
#
# <h3> Response </h3>
#
# - Removed these three classifiers from the list of models being used

# %%
remove_index = [5,7]
models = [i for j, i in enumerate(models) if j not in remove_index]

# %%
X_train = drop_player_name_and_label(init_X_train)
X_test = drop_player_name_and_label(init_X_test)

X_train_scaled, X_test_scaled = standard_scale(X_train, X_test)

# %%
norm_tables = []
adv_tables = []
filtered_tables = []

for filepath in glob.iglob('recent-nba-players-stats/*.csv'):
    df = pd.read_csv(filepath, index_col=0)  
    df = df.query('G >= 30')
    if '_adv' in filepath:
        df = df[['Player', 'Pos', 'USG%', 'AST%', 'STL%', 'BLK%']]
        df.fillna(0, inplace=True)
        df = df.groupby('Player').mean()
        df = df.round(2).reset_index()
        adv_tables.append(df)       
    else:
        df = df[['Player', 'Pos', 'G', 'MP', '3P', '3P%', '2P','2P%','FT', 'FT%', 
                 'ORB', 'DRB',  'AST', 'STL', 'BLK', 'TOV', 'PTS']]
        df.fillna(0, inplace=True)
        df = df.groupby('Player').mean()
        df = df.round(2).reset_index()
        df[['2P%', '3P%', 'FT%']] = df[['2P%', '3P%', 'FT%']] * 100
        norm_tables.append(df)      

for n_df, adv_df in zip(norm_tables, adv_tables):
    merged_df = pd.merge(n_df, adv_df, on="Player")  
    merged_df[countable_columns]  = merged_df[countable_columns] .div(merged_df['G'].values,axis=0)
    merged_df.rename(columns={'MP':'MP/G','2P':'2P/G','3P':'3P/G','FT':'FT/G'
                                     ,'ORB':'ORB/G','DRB':'DRB/G','AST':'AST/G','STL':'STL/G'
                                     ,'BLK':'BLK/G','TOV':'TOV/G','PTS':'PTS/G'}, inplace=True)
    merged_df.drop(['G'], axis=1, inplace=True)
    merged_df = merged_df.round(2)
    merged_df['Player'] = merged_df['Player'].str.split(r"\\|=", expand=True)
    merged_df = merged_df.reindex(columns=season_stats_filtered.columns)
    filtered_tables.append(merged_df)

joined_df = pd.concat([filtered_tables[0],filtered_tables[1],filtered_tables[2],
                       filtered_tables[3],filtered_tables[4]], axis=0)
joined_df = joined_df.groupby('Player').mean().round(2).reset_index()

X_test_recent_player = drop_player_name_and_label(joined_df)
X_test_scaled_recent_player = X_scaler.transform(X_test_recent_player)

# %%
TP_list_agg = [] ## Hall of Famer
TN_list_agg = [] ## Non Hall of Famer
FP_list_agg = [] ## Non Hall of Famer being predicted as Hall of Famer
FN_list_agg = [] ## Hall of Famer being predicted as Non Hall of Famer
current_player_list_agg = []
current_player_proba_agg = []

for model_dict in models:
    
    TP_list = [] ## Hall of Famer
    TN_list = [] ## Non Hall of Famer
    FP_list = [] ## Non Hall of Famer being predicted as Hall of Famer
    FN_list = [] ## Hall of Famer being predicted as Non Hall of Famer
    current_player_list = []
    
    name = model_dict['name']
    estimator = model_dict['estimator']
    
    model = estimator.fit(X_train_scaled, init_y_train)
    y_prediction = model.predict(X_test_scaled)
    
    y_test_np = y_test.to_numpy()
    
    print("==> Checking which players are Hall of Famer according to {} ...".format(name))  
   
    for i in range(len(X_test_scaled)):
        player_name = init_X_test.iloc[i]['Player']
        if ((y_test_np[i] == 0) and (y_prediction[i] == 0)):   # TN

            TN_list.append(player_name)
        elif ((y_test_np[i] == 0) and (y_prediction[i] == 1)): # FP
           
            FP_list.append(player_name)
        elif ((y_test_np[i] == 1) and (y_prediction[i] == 0)): # FN
            
            FN_list.append(player_name)
        else:                                                # TP
           
            TP_list.append(player_name)
    
    print("--> # of HoF predicted to be HoF = {:>3} (TP)".format(len(TP_list)))
    print("--> # of HoF predicted to be non-HoF = {:>3} (FN)".format(len(FN_list)))
    print("--> # of non-HoF predicted to be HoF = {:>3} (FP)".format(len(FP_list)))
    print("--> # of non-HoF predicted to be non-HoF = {:>3} (TN)".format(len(TN_list)))
    print("")
    print("--> # of HoF predicted to be HoF", TP_list)
    print(" ")
    print("--> # of HoF predicted to be non-HoF", FN_list)
    print(" ")
    print("--> # of non-HoF predicted to be HoF", FP_list)
    print(" ")

    TP_list_agg.append(TP_list)
    TN_list_agg.append(TN_list)
    FP_list_agg.append(FP_list)
    FN_list_agg.append(FN_list)
    
    y_pred_recent_player = model.predict(X_test_scaled_recent_player)
    y_proba_recent_player = model.predict_proba(X_test_scaled_recent_player)[:,1] 
    current_player_proba_agg.append(y_proba_recent_player)
    
    for i in range(len(X_test_scaled_recent_player)):
        player_name = joined_df.iloc[i]['Player']
        if y_pred_recent_player[i] == 1:
            current_player_list.append(player_name)
        else:
            continue

    current_player_list_agg.append(current_player_list)
# Out:
# ==> Checking which players are Hall of Famer according to K-Nearest Neighbours Classifier ...
# --> # of HoF predicted to be HoF =   3 (TP)
# --> # of HoF predicted to be non-HoF =  11 (FN)
# --> # of non-HoF predicted to be HoF =   2 (FP)
# --> # of non-HoF predicted to be non-HoF = 523 (TN)
#
# --> # of HoF predicted to be HoF ['Kareem Abdul-Jabbar', 'Michael Jordan', 'Adrian Dantley']
#
# --> # of HoF predicted to be non-HoF ['Clyde Drexler', 'Calvin Murphy', 'James Worthy', 'Rick Barry', 'Earl Monroe', 'Dikembe Mutombo', 'Charles Barkley', 'Joe Dumars', 'Allen Iverson', 'John Stockton', 'Dennis Rodman']
#
# --> # of non-HoF predicted to be HoF ['DeMarcus Cousins', 'Anthony Davis']
#
# ==> Checking which players are Hall of Famer according to Logistic Regression Classifier ...
# --> # of HoF predicted to be HoF =   5 (TP)
# --> # of HoF predicted to be non-HoF =   9 (FN)
# --> # of non-HoF predicted to be HoF =   4 (FP)
# --> # of non-HoF predicted to be non-HoF = 521 (TN)
#
# ...

# %%
model_for_ensemble = []

for _, model in enumerate(models, 0):
    model_for_ensemble.append((model['name'], model['estimator']))
    
ensemble = VotingClassifier(estimators=model_for_ensemble, voting='hard')


ensemble.fit(X_train_scaled,init_y_train)
y_prediction_ens = ensemble.predict(X_test_scaled)

TP_list = []
FN_list = []
FP_list = []
TN_list = []

for i in range(len(X_test_scaled)):
    player_name = init_X_test.iloc[i]['Player']
    if ((y_test_np[i] == 0) and (y_prediction_ens[i] == 0)):   # TN

        TN_list.append(player_name)
    elif ((y_test_np[i] == 0) and (y_prediction[i] == 1)): # FP

        FP_list.append(player_name)
    elif ((y_test_np[i] == 1) and (y_prediction[i] == 0)): # FN

        FN_list.append(player_name)
    else:                                                # TP

        TP_list.append(player_name)

FP_list_agg.append(FP_list)
FN_list_agg.append(FN_list)
        
print("--> # of HoF predicted to be HoF = {:>3} (TP)".format(len(TP_list)))
print("--> # of HoF predicted to be non-HoF = {:>3} (FN)".format(len(FN_list)))
print("--> # of non-HoF predicted to be HoF = {:>3} (FP)".format(len(FP_list)))
print("--> # of non-HoF predicted to be non-HoF = {:>3} (TN)".format(len(TN_list)))
print("")
# Out:
# --> # of HoF predicted to be HoF =   7 (TP)
# --> # of HoF predicted to be non-HoF =   8 (FN)
# --> # of non-HoF predicted to be HoF =   2 (FP)
# --> # of non-HoF predicted to be non-HoF = 522 (TN)

# %%
print("--> # of HoF predicted to be HoF", TP_list)
print(" ")
print("--> # of HoF predicted to be non-HoF", FN_list)
print(" ")
print("--> # of non-HoF predicted to be HoF", FP_list)
print(" ")
# Out:
# --> # of HoF predicted to be HoF ['Kareem Abdul-Jabbar', 'Clyde Drexler', 'Michael Jordan', 'Anthony Davis', 'Adrian Dantley', 'Charles Barkley', 'Allen Iverson']
#
# --> # of HoF predicted to be non-HoF ['Calvin Murphy', 'James Worthy', 'Rick Barry', 'Earl Monroe', 'Dikembe Mutombo', 'Joe Dumars', 'John Stockton', 'Dennis Rodman']
#
# --> # of non-HoF predicted to be HoF ['Dwyane Wade', 'LeBron James']

# %%
TP_list_agg = flat_and_dup(TP_list_agg)
TN_list_agg = flat_and_dup(TN_list_agg)
FN_list_agg = flat_and_dup(FN_list_agg)
FP_list_agg = flat_and_dup(FP_list_agg)

# %%
print("--> Aggregate Hall of Famers model predicted to be non hall of famer", FN_list_agg)
print(" ")
print("--> Aggregate Non Hall of Famers model predict to be Hall of Famers", FP_list_agg)
print(" ")
print("--> Aggregate Hall of Famers model predict to be Hall of Famers", TP_list_agg)
print(" ")
# Out:
# --> Aggregate Hall of Famers model predicted to be non hall of famer ['Clyde Drexler', 'Calvin Murphy', 'James Worthy', 'Rick Barry', 'Earl Monroe', 'Dikembe Mutombo', 'Charles Barkley', 'Joe Dumars', 'Allen Iverson', 'John Stockton', 'Dennis Rodman', 'Michael Jordan']
#
# ...

# %%
df_all_hof = season_stats_filtered.query("isHoF == 1")
df_FN = season_stats_filtered[season_stats_filtered['Player'].isin(FN_list_agg)]
df_FP = season_stats_filtered[season_stats_filtered['Player'].isin(FP_list_agg)]

# %%
frequency_hof = dict(Counter([item for sublist in current_player_list_agg for item in sublist]))

prob_arr_sum = np.sum(current_player_proba_agg, 0) /len(current_player_proba_agg)

prob_arr_dict = []
for i in range(len(X_test_scaled_recent_player)):
        player_name = joined_df.iloc[i]['Player']
        player_prob_dict = {'name': player_name, 'probability': prob_arr_sum[i].round(4)}
        prob_arr_dict.append(player_prob_dict)


prob_hof = sorted(prob_arr_dict, key = lambda i: i['probability'],reverse=True)

prob_hof
# Out:
# [{'name': 'Anthony Davis', 'probability': 0.7228},
#  {'name': 'Dwyane Wade', 'probability': 0.7082},
#  {'name': 'LeBron James', 'probability': 0.6682},
#  {'name': 'Dwight Howard', 'probability': 0.5907},
#  {'name': 'LaMarcus Aldridge', 'probability': 0.5104},
#  {'name': 'DeMarcus Cousins', 'probability': 0.5023},
#  {'name': 'Andrew Bynum', 'probability': 0.4514},
#  {'name': 'Kevin Durant', 'probability': 0.4168},
#  {'name': 'Brook Lopez', 'probability': 0.3734},
#  {'name': 'Monta Ellis', 'probability': 0.3727},
#  {'name': 'Al Horford', 'probability': 0.3708},
#  {'name': 'Rudy Gay', 'probability': 0.3448},
#  {'name': 'Blake Griffin', 'probability': 0.3191},
#  {'name': 'Hassan Whiteside', 'probability': 0.2824},
#  {'name': 'Serge Ibaka', 'probability': 0.2796},
#  {'name': 'Carmelo Anthony', 'probability': 0.271},
#  {'name': 'John Wall', 'probability': 0.2657},
#  {'name': 'Kevin Love', 'probability': 0.263},
#  {'name': 'Pau Gasol', 'probability': 0.2561},
# ...
