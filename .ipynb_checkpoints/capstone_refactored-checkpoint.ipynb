# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statistics 
import sklearn.metrics as metrics
import glob
import pickle

from functools   import reduce
from collections import Counter

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest,chi2

from sklearn.linear_model          import LogisticRegression, SGDClassifier, PassiveAggressiveClassifier
from sklearn.neighbors             import KNeighborsClassifier
from sklearn.svm                   import SVC
from sklearn.tree                  import DecisionTreeClassifier
from sklearn.ensemble              import RandomForestClassifier,VotingClassifier,GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,plot_confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from imblearn.over_sampling import SMOTE

import seaborn as sns
# %matplotlib inline

season_stats = pd.read_csv('nba-players-stats/Seasons_Stats.csv', index_col=0)

# %%
season_stats.columns
# Out:
# Index(['Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM',
#        'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
#        '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
countable_columns = ['MP','2P','3P', 'FT','ORB','DRB','AST','STL','BLK','PTS']
independent_features = ['Player', 'MP', 'Pos', 'G', '2P', '2P%', '3P', '3P%', 'FT', 'FT%', 'USG%', 'ORB', 'DRB', 'AST', 'STL',  'BLK',  'PTS', 
                        'OWS', 'DWS', 'WS','OBPM', 'DBPM','BPM', 'VORP', 'isHoF']

## Current dataset only contains Hall of Famers until 2016 Inductee. Custom Inductees are added from 2012 to current
custom_inductee = ['Tracy McGrady', "George McGinnis", "Ray Allen", "Maurice Cheeks", "Grant Hill", "Jason Kidd",
                  'Steve Nash', 'Dino Radja', 'Vlade Divac', 'Bobby Jones', 'Sidney Moncrief', 'Jack Sikma','Tim Duncan',
                  'Kevin Garnett', 'Kobe Bryant', 'Shawn Marion', 'Chauncey Billups']

# %%
def hof_column_transformer(df):
    hof_container = df.copy()
    hof_container['Player'] = hof_container['Player'].str.replace("*", "_hof")
    hof_container = hof_container[hof_container['Player'].str.contains("_hof")]['Player'].str.replace("_hof", "*").unique()
    df['isHoF'] = ''
    df['isHoF'] = np.where(df['Player'].isin(hof_container), 1,0)
    df['Player'] = df['Player'].str.replace("*", "")
    return df

def div_by_game_and_rename_column(df):
    df[countable_columns]  = df[countable_columns].div(df['G'].values,axis=0)
    df.rename(columns={'MP':'MP/G','2P':'2P/G','3P':'3P/G','FT':'FT/G'
                                         ,'ORB':'ORB/G','DRB':'DRB/G','AST':'AST/G','STL':'STL/G'
                                         ,'BLK':'BLK/G','TOV':'TOV/G','PTS':'PTS/G'}, inplace=True)
    df.drop(['G'], axis=1, inplace=True)
    return df

def normalize_percentiles(df):
    df[['2P%', '3P%', 'FT%']] = df[['2P%', '3P%', 'FT%']] * 100
    df = df.round(2)
    return df
    
def filter_by_30_games(df):
    df.query('G >= 30')
    return df

def train_test_splitter(df):
    
    X = df
    y = df['isHoF']
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25, random_state=10, stratify =y)
    return  X_train,X_test,y_train,y_test

def generate_plot_df(X_train, y_train):
    
    df_plot = pd.DataFrame(data=X_train[1:], columns=X_train.columns[1:])
    df_plot['isHoF'] = y_train
    df_plot_hof  = df_plot[df_plot['isHoF'] == 1]
    df_plot_nhof  = df_plot[df_plot['isHoF'] == 0]
    return df_plot, df_plot_hof, df_plot_nhof

def generate_plt(plot_1, plot_2, plot_1_label, plot_2_label):
    plt.figure(figsize=(15, 15))
    for i, feature in enumerate(plot_1.columns[1:-1]):
        plt.subplot(5, 5, i+1)
        sns.distplot(plot_1[feature], bins=10, color="#5d80ff",
                      kde_kws={"label": plot_1_label},
                      hist_kws={"linewidth": 1,
                                "alpha": 0.5,"color": "#5d80ff"})
        sns.distplot(plot_2[feature], bins=10, color="#ffcc5d",
                      kde_kws={"label": plot_2_label},
                      hist_kws={"linewidth": 1,
                                "alpha": 0.5,"color": "#ffcc5d"})
        plt.xlabel(feature)
        plt.ylabel('Probability Density')
        plt.grid(True)
        plt.tight_layout()

def drop_player_name_and_label(X):
    X = X.drop(['Player', 'isHoF'],axis=1)
    return X

def standard_scale(X_train, X_test):
    X_scaler = StandardScaler(with_mean=True, with_std=True) 
    X_train_scaled = X_scaler.fit_transform(X_train) 
    X_test_scaled  = X_scaler.transform(X_test)
    return X_scaler, X_train_scaled, X_test_scaled

def custom_inductee_update(df):
    df[df['Player'].isin(custom_inductee)]
    df.loc[df.Player.isin(custom_inductee), 'isHoF'] = 1
    return df

def is_outlier(s):
    lower_limit = s.mean() - (s.std() * 0.25)
    upper_limit = s.mean() + (s.std() * 3.5)
    return ~s.between(lower_limit, upper_limit)

def low_max_detection(df):
    q_low = df["MP/G"].quantile(0.15)
    q_hi  = df["MP/G"].quantile(0.75)
    df = df[(df["MP/G"] < q_hi) & (df["MP/G"] > q_low)]
    return df

def estimator_dict(name, estimator):
    model = {'name':name, 'estimator':estimator}
    return model

# %% [markdown]
# <h4> Data cleaning for historical data and recent players </h4>

# %%
## Data Filter / Data Clean / Hall of Fame column

## Players past 1980 and minimum number of games > 30 are used for evaluation
season_stats_filtered = season_stats.copy()
season_stats_filtered = season_stats.query('Year >= 1980')
season_stats_filtered = filter_by_30_games(season_stats_filtered)

## Removed columns with no predictive power
season_stats_filtered.drop(['GS','blanl','blank2','blank2','Age', 'Tm'], axis=1, inplace=True)

## All the null values are handled - these values are null because there is 0 sample for the percentiles - thus 0.
season_stats_filtered.fillna(0, inplace=True)
season_stats_filtered = hof_column_transformer(season_stats_filtered)
season_stats_filtered = custom_inductee_update(season_stats_filtered)


season_stats_filtered = season_stats_filtered[independent_features]

season_stats_filtered = div_by_game_and_rename_column(season_stats_filtered)
season_stats_filtered = season_stats_filtered[~season_stats_filtered.groupby('Player')['MP/G'].apply(is_outlier)].reset_index(drop=True)
# season_stats_filtered = low_max_detection(season_stats_filtered)
# season_stats_filtered = season_stats_filtered[(season_stats_filtered['Pos'] == 'PF') | (season_stats_filtered['Pos'] == 'C') | (season_stats_filtered['Pos'] == 'PF-C')]
season_stats_filtered = season_stats_filtered.groupby('Player').mean().reset_index()
season_stats_filtered['isHoF'] = np.where(season_stats_filtered['isHoF'] == 0, 0, 1)
season_stats_filtered = normalize_percentiles(season_stats_filtered)

# %%
norm_tables = []
adv_tables = []
filtered_tables = []

for filepath in glob.iglob('recent-nba-players-stats/*.csv'):
    df = pd.read_csv(filepath, index_col=0)  
    df = filter_by_30_games(df)
    if '_adv' in filepath:
        df = df[['Player', 'Pos', 'USG%','OWS', 'DWS', 'WS','OBPM', 'DBPM','BPM', 'VORP']]
        df.fillna(0, inplace=True)
        df = df.groupby('Player').mean()
        df = df.round(2).reset_index()
        adv_tables.append(df)       
    else:
        df = df[['Player', 'Pos', 'G', 'MP', '3P', '3P%', '2P','2P%','FT', 'FT%', 
                 'ORB', 'DRB',  'AST', 'STL', 'BLK', 'PTS']]
        df.fillna(0, inplace=True)
        df = df.groupby('Player').mean()
        df = df.round(2).reset_index()
        norm_tables.append(df)      

for n_df, adv_df in zip(norm_tables, adv_tables):
    merged_df = pd.merge(n_df, adv_df, on="Player")  
    merged_df = div_by_game_and_rename_column(merged_df)
    merged_df = merged_df.round(2)
    
    
    merged_df['Player'] = merged_df['Player'].str.split(r"\\|=", expand=True)
    
    merged_df = merged_df.reindex(columns=merged_df.columns)
    filtered_tables.append(merged_df)

joined_df = pd.concat([filtered_tables[0],filtered_tables[1],filtered_tables[2],
                       filtered_tables[3],filtered_tables[4]], axis=0)
joined_df = joined_df.groupby('Player').mean().round(2)

joined_df = joined_df[season_stats_filtered.columns[1:-1]]
joined_df = joined_df.reset_index()

# %% [markdown]
# <h4> Initial EDA </h4>

# %%
X_train,X_test,y_train,y_test = train_test_splitter(season_stats_filtered)

# %%
df_plot, df_plot_hof, df_plot_nhof = generate_plot_df(X_train, y_train)
generate_plt(df_plot_hof, df_plot_nhof, 'hof', 'nhof')

# %%
models = []

models.append(estimator_dict('K-Nearest Neighbours Classifier', KNeighborsClassifier(n_neighbors=5, weights='uniform')))
models.append(estimator_dict('Logistic Regression Classifier', LogisticRegression(C=0.1, random_state=10)))
models.append(estimator_dict('SVM Classifier', SVC(probability=True, random_state=10)))
models.append(estimator_dict('Stochastic Gradient Descent Classifier', SGDClassifier(loss="log", random_state=10)))
models.append(estimator_dict('Gaussian Naive Bayes Classifier', GaussianNB()))
models.append(estimator_dict('Decision Tree Classifier', DecisionTreeClassifier(max_depth=10, max_features='auto', random_state=10)))
models.append(estimator_dict('Random Forest Classifier', RandomForestClassifier(n_estimators=200, max_depth=None, max_features='auto', random_state=10)))
models.append(estimator_dict('Adaptive Boosted Decision Tree Classifier', AdaBoostClassifier(n_estimators=200, learning_rate=0.1, random_state=10)))
models.append(estimator_dict('Gradient Boosted Decision Tree Classifier', GradientBoostingClassifier(n_estimators=200, max_depth=10, learning_rate=0.1, random_state=10)))

# %%
# ## TODO: Get Data that confident and not confident

# ## Function that will:
# ## Get df
# ## Scale it
# ## Run it through threshhold
# ## Find y_proba scores
# ## Set the threshhold - rows that does not pass that, store it in 'non-confident' classification df
# ## return confident df and non-confident df
# ## feed confident df through model

# def uncertain_removal()
#     for model_dict in models:
        
        
#         estimator = model_dict['estimator']
#         model = estimator.fit(X_train_scaled, y_train)
#         y_pred = model.predict(X_test_scaled)

#         tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
#         thresholds = np.arange(0.25, 0.75, 0.01)
#         precisions = list()
#         recalls = list()
#         f1_list = list()
#         roc_auc_list = list()
        
#         ## Df: player, pred_proba,label, true_label

#         for threshold in thresholds:
#             y_proba = model.predict_proba(X_test_scaled)[:,1]
#             y_threshold = np.where(y_proba > threshold, 1, 0)
#             precision = precision_score(y_test, y_threshold)
#             recall = recall_score(y_test, y_threshold)
#             roc_auc = roc_auc_score(y_test, y_proba)
#             f1 = f1_score(y_test, y_pred)
            
#             precisions.append(precision)
#             recalls.append(recall)
#             f1_list.append(f1)
#             roc_auc_list.append(roc_auc)

#         model_val = {"name": name, "precision_mean" : statistics.mean(precisions), 
#                      "recall_mean" : statistics.mean(recalls),
#                      "f1_mean":statistics.mean(f1_list), 'TP': tp,
#                      "TN": tn, "FP": fp, "FN": fn, 'roc_auc': statistics.mean(roc_auc_list).round(2)
#                     }
        
        
#         model_vals.append(model_val)

# %% [markdown]
# <h4> Model Training , Model Evaluation, and Imbalanced Model Training by SMOTE </h4>

# %%
init_X_train = X_train.copy()
init_X_test = X_test.copy()
init_y_train = y_train.copy()
init_y_test = y_test.copy()

# %%
X_train = drop_player_name_and_label(X_train)
X_test = drop_player_name_and_label(X_test)

X_scaler, X_train_scaled, X_test_scaled = standard_scale(X_train, X_test)

smote = SMOTE(sampling_strategy='auto', k_neighbors=2)
X_train_scaled, y_train = smote.fit_resample(X_train_scaled, y_train)

# %%
model_vals = []
df_summary_lists = []
     
with open("models.pckl", "wb") as f:
    for model_dict in models:

        name = model_dict['name']
        estimator = model_dict['estimator']

        print("doing estimation on...", model_dict['name'])

        model = estimator.fit(X_train_scaled, y_train)
        y_pred = model.predict(X_test_scaled)
#         y_pred = (estimator.predict_proba(X_test_scaled)[:,1] >= 0.85).astype(bool)
        pickle.dump(model, f)

        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
        thresholds = np.arange(0.25, 0.75, 0.01)
        precisions = list()
        recalls = list()
        f1_list = list()
        roc_auc_list = list()
        
        ## Df: player, pred_proba,label, true_label

        for threshold in thresholds:
            y_proba = model.predict_proba(X_test_scaled)[:,1]
            y_threshold = np.where(y_proba > threshold, 1, 0)
            precision = precision_score(y_test, y_threshold)
            recall = recall_score(y_test, y_threshold)
            roc_auc = roc_auc_score(y_test, y_proba)
            f1 = f1_score(y_test, y_pred)
            acc_score = accuracy_score(y_pred, y_test)
            
            precisions.append(precision)
            recalls.append(recall)
            f1_list.append(f1)
            roc_auc_list.append(roc_auc)

        model_val = {"name": name, "precision_mean" : statistics.mean(precisions), 
                     "recall_mean" : statistics.mean(recalls),
                     "f1_mean":statistics.mean(f1_list),'accuracy_score':acc_score, 'TP': tp,
                     "TN": tn, "FP": fp, "FN": fn, 'roc_auc': statistics.mean(roc_auc_list).round(2)
                    }
        
        
        model_vals.append(model_val)
    
df_sum = pd.DataFrame.from_dict(model_vals)
df_summary_lists.append(df_sum)

display(df_sum)
# Out:
# doing estimation on... K-Nearest Neighbours Classifier
# doing estimation on... Logistic Regression Classifier
# doing estimation on... SVM Classifier
# doing estimation on... Stochastic Gradient Descent Classifier
# doing estimation on... Gaussian Naive Bayes Classifier
# doing estimation on... Decision Tree Classifier
# doing estimation on... Random Forest Classifier
# doing estimation on... Adaptive Boosted Decision Tree Classifier
# doing estimation on... Gradient Boosted Decision Tree Classifier
#                                         name  precision_mean  recall_mean  \
# 0            K-Nearest Neighbours Classifier        0.341941     0.806667
# 1             Logistic Regression Classifier        0.231287     0.925556
# 2                             SVM Classifier        0.307923     0.602222
# 3     Stochastic Gradient Descent Classifier        0.230166     0.654444
# 4            Gaussian Naive Bayes Classifier        0.194566     1.000000
# 5                   Decision Tree Classifier        0.258065     0.444444
# 6                   Random Forest Classifier        0.354755     0.491111
# 7  Adaptive Boosted Decision Tree Classifier        0.174388     0.577778
# 8  Gradient Boosted Decision Tree Classifier        0.269268     0.436667
#
#     f1_mean  accuracy_score  TP   TN  FP  FN  roc_auc
# 0  0.483871        0.942959  15  514  29   3     0.89
# 1  0.382022        0.901961  17  489  54   1     0.97
# 2  0.394366        0.923351  14  504  39   4     0.96
# 3  0.358209        0.923351  12  506  37   6     0.94
# 4  0.327273        0.868093  18  469  74   0     0.97
# 5  0.326531        0.941176   8  520  23  10     0.70
# 6  0.418605        0.955437   9  527  16   9     0.96
# 7  0.383562        0.919786  14  502  41   4     0.96
# 8  0.375000        0.946524   9  522  21   9     0.92

# %% [markdown]
# <h4>Loading pre-trained model</h4>

# %%
loaded_models = []
with open("models.pckl", "rb") as f:
    while True:
        try:
            loaded_models.append(pickle.load(f))
        except EOFError:
            break

# %%
TP_list_agg = [] ## Hall of Famer
TN_list_agg = [] ## Non Hall of Famer
FP_list_agg = [] ## Non Hall of Famer being predicted as Hall of Famer
FN_list_agg = [] ## Hall of Famer being predicted as Non Hall of Famer

for model in loaded_models:
    
    TP_list = [] ## Hall of Famer
    TN_list = [] ## Non Hall of Famer
    FP_list = [] ## Non Hall of Famer being predicted as Hall of Famer
    FN_list = [] ## Hall of Famer being predicted as Non Hall of Famer
    current_player_list = []
    
    name = type(model).__name__
  
    y_prediction = model.predict(X_test_scaled)  
    y_test_np = y_test.to_numpy()
    
    print("==> Checking which players are Hall of Famer according to {} ...".format(name))  
   
    for i in range(len(X_test_scaled)):
        player_name = init_X_test.iloc[i]['Player']
        if ((y_test_np[i] == 0) and (y_prediction[i] == 0)):   # TN

            TN_list.append(player_name)
        elif ((y_test_np[i] == 0) and (y_prediction[i] == 1)): # FP
           
            FP_list.append(player_name)
        elif ((y_test_np[i] == 1) and (y_prediction[i] == 0)): # FN
            
            FN_list.append(player_name)
        else:                                                # TP
           
            TP_list.append(player_name)
    
    print("--> # of HoF predicted to be HoF = {:>3} (TP)".format(len(TP_list)))
    print("--> # of HoF predicted to be non-HoF = {:>3} (FN)".format(len(FN_list)))
    print("--> # of non-HoF predicted to be HoF = {:>3} (FP)".format(len(FP_list)))
    print("--> # of non-HoF predicted to be non-HoF = {:>3} (TN)".format(len(TN_list)))
    print("")
    print("--> # of HoF predicted to be HoF", TP_list)
    print(" ")
    print("--> # of HoF predicted to be non-HoF", FN_list)
    print(" ")
    print("--> # of non-HoF predicted to be HoF", FP_list)
    print(" ")

    TP_list_agg.append(TP_list)
    TN_list_agg.append(TN_list)
    FP_list_agg.append(FP_list)
    FN_list_agg.append(FN_list)
# Out:
# ==> Checking which players are Hall of Famer according to KNeighborsClassifier ...
# --> # of HoF predicted to be HoF =  15 (TP)
# --> # of HoF predicted to be non-HoF =   3 (FN)
# --> # of non-HoF predicted to be HoF =  29 (FP)
# --> # of non-HoF predicted to be non-HoF = 514 (TN)
#
# --> # of HoF predicted to be HoF ['Michael Jordan', 'Patrick Ewing', 'Gary Payton', 'Yao Ming', 'Drazen Petrovic', 'Chris Mullin', 'Scottie Pippen', 'David Robinson', 'Wes Unseld', 'Tim Duncan', 'Larry Bird', 'Kevin Garnett', 'Tracy McGrady', 'John Stockton', 'Jamaal Wilkes']
#
# --> # of HoF predicted to be non-HoF ['Jack Sikma', 'Dave Cowens', 'Calvin Murphy']
#
# --> # of non-HoF predicted to be HoF ['World B.', 'Chris Webber', 'Gus Williams', 'Chris Paul', 'John Williamson', 'Reggie Lewis', 'Joe Barry', 'Roy Hinson', 'Derrick McKey', 'Vern Fleming', 'Dirk Nowitzki', 'Detlef Schrempf', 'Kiki Vandeweghe', 'Kyle Lowry', 'Mookie Blaylock', 'Tony Parker', 'Mark Price', 'Al Jefferson', 'Ty Lawson', 'Steve Stipanovich', 'Michael Redd', 'Jerome Kersey', 'Jeff Malone', 'Jusuf Nurkic', 'Gorgui Dieng', 'Anthony Davis', 'Freeman Williams', 'Stephen Curry', 'Charles Smith']
#
# ==> Checking which players are Hall of Famer according to LogisticRegression ...
# --> # of HoF predicted to be HoF =  17 (TP)
# --> # of HoF predicted to be non-HoF =   1 (FN)
# --> # of non-HoF predicted to be HoF =  54 (FP)
# --> # of non-HoF predicted to be non-HoF = 489 (TN)
#
# --> # of HoF predicted to be HoF ['Michael Jordan', 'Jack Sikma', 'Patrick Ewing', 'Dave Cowens', 'Gary Payton', 'Yao Ming', 'Chris Mullin', 'Scottie Pippen', 'David Robinson', 'Wes Unseld', 'Tim Duncan', 'Larry Bird', 'Kevin Garnett', 'Tracy McGrady', 'John Stockton', 'Jamaal Wilkes', 'Calvin Murphy']
#
# --> # of HoF predicted to be non-HoF ['Drazen Petrovic']
#
# --> # of non-HoF predicted to be HoF ['Caldwell Jones', 'Eddie Jones', 'World B.', 'Mychal Thompson', 'Chris Bosh', 'Chris Webber', 'Danny Fortson', 'Bryant Reeves', 'Bill Cartwright', 'Kristaps Porzingis', 'Gus Williams', 'Chris Paul', 'Reggie Lewis', 'Joe Barry', 'Roy Hinson', 'Vern Fleming', "Amar'e Stoudemire", 'Dirk Nowitzki', 'Derrick Rose', 'Armen Gilliam', 'Anfernee Hardaway', 'Detlef Schrempf', 'Elton Brand', 'Kiki Vandeweghe', 'Clarence Weatherspoon', 'James Silas', 'Jeff Ruland', 'Elden Campbell', 'Tim Hardaway', 'Mike Gminski', 'Jalen Rose', 'Damian Lillard', 'Danny Manning', 'Roy Hibbert', 'Clark Kellogg', 'Kyle Lowry', 'Myles Turner', 'Tony Parker', 'Andrew Toney', 'Mark Price', 'Swen Nater', 'Al Jefferson', 'Christian Laettner', 'Ty Lawson', 'Steve Stipanovich', 'Paul Pierce', 'Michael Redd', 'James Donaldson', 'Jeff Malone', 'Scott Skiles', 'Nikola Vucevic', 'Anthony Davis', 'Stephen Curry', 'Vince Carter']
#
# ==> Checking which players are Hall of Famer according to SVC ...
# --> # of HoF predicted to be HoF =  14 (TP)
# --> # of HoF predicted to be non-HoF =   4 (FN)
# --> # of non-HoF predicted to be HoF =  39 (FP)
# --> # of non-HoF predicted to be non-HoF = 504 (TN)
#
# --> # of HoF predicted to be HoF ['Jack Sikma', 'Patrick Ewing', 'Dave Cowens', 'Gary Payton', 'Yao Ming', 'Chris Mullin', 'Scottie Pippen', 'David Robinson', 'Wes Unseld', 'Tim Duncan', 'Larry Bird', 'Kevin Garnett', 'John Stockton', 'Calvin Murphy']
#
# --> # of HoF predicted to be non-HoF ['Michael Jordan', 'Drazen Petrovic', 'Tracy McGrady', 'Jamaal Wilkes']
#
# --> # of non-HoF predicted to be HoF ['Darryl Dawkins', 'World B.', 'Mychal Thompson', 'Chris Bosh', 'Chris Webber', 'Gus Williams', 'Chris Paul', 'John Williamson', 'Reggie Lewis', 'Joe Barry', 'Roy Hinson', 'Hersey Hawkins', "Amar'e Stoudemire", 'Dirk Nowitzki', 'Derrick Rose', 'Anfernee Hardaway', 'Detlef Schrempf', 'Elton Brand', 'Kiki Vandeweghe', 'James Silas', 'Jeff Ruland', 'Elden Campbell', 'Tim Hardaway', 'Danny Manning', 'Kyle Lowry', 'Myles Turner', 'Tony Parker', 'Andrew Toney', 'Mark Price', 'Al Jefferson', 'Christian Laettner', 'Ty Lawson', 'Steve Stipanovich', 'Paul Pierce', 'Michael Redd', 'Jeff Malone', 'Jusuf Nurkic', 'Anthony Davis', 'Stephen Curry']
#
# ==> Checking which players are Hall of Famer according to SGDClassifier ...
# --> # of HoF predicted to be HoF =  12 (TP)
# --> # of HoF predicted to be non-HoF =   6 (FN)
# --> # of non-HoF predicted to be HoF =  37 (FP)
# --> # of non-HoF predicted to be non-HoF = 506 (TN)
#
# --> # of HoF predicted to be HoF ['Michael Jordan', 'Jack Sikma', 'Patrick Ewing', 'Yao Ming', 'Chris Mullin', 'David Robinson', 'Wes Unseld', 'Tim Duncan', 'Larry Bird', 'Kevin Garnett', 'Tracy McGrady', 'John Stockton']
#
# --> # of HoF predicted to be non-HoF ['Dave Cowens', 'Gary Payton', 'Drazen Petrovic', 'Scottie Pippen', 'Jamaal Wilkes', 'Calvin Murphy']
#
# --> # of non-HoF predicted to be HoF ['Darryl Dawkins', 'Caldwell Jones', 'World B.', 'Mychal Thompson', 'Chris Bosh', 'Jayson Williams', 'Chris Webber', 'Danny Fortson', 'Bryant Reeves', 'Bill Cartwright', 'Kristaps Porzingis', 'Pavel Podkolzin', 'Reggie Lewis', 'Joe Barry', 'Roy Hinson', "Amar'e Stoudemire", 'Dirk Nowitzki', 'Derrick Rose', 'Armen Gilliam', 'Detlef Schrempf', 'Elton Brand', 'Kiki Vandeweghe', 'James Silas', 'Jeff Ruland', 'Elden Campbell', 'Mike Gminski', 'Clark Kellogg', 'Myles Turner', 'Swen Nater', 'Al Jefferson', 'Christian Laettner', 'Steve Stipanovich', 'Paul Pierce', 'James Donaldson', 'Nikola Vucevic', 'Anthony Davis', 'Eddy Curry']
#
# ==> Checking which players are Hall of Famer according to GaussianNB ...
# --> # of HoF predicted to be HoF =  18 (TP)
# --> # of HoF predicted to be non-HoF =   0 (FN)
# --> # of non-HoF predicted to be HoF =  74 (FP)
# --> # of non-HoF predicted to be non-HoF = 469 (TN)
#
# --> # of HoF predicted to be HoF ['Michael Jordan', 'Jack Sikma', 'Patrick Ewing', 'Dave Cowens', 'Gary Payton', 'Yao Ming', 'Drazen Petrovic', 'Chris Mullin', 'Scottie Pippen', 'David Robinson', 'Wes Unseld', 'Tim Duncan', 'Larry Bird', 'Kevin Garnett', 'Tracy McGrady', 'John Stockton', 'Jamaal Wilkes', 'Calvin Murphy']
#
# --> # of HoF predicted to be non-HoF []
#
# --> # of non-HoF predicted to be HoF ['Jason Richardson', 'Eddie Jones', 'World B.', 'Mychal Thompson', 'Chris Bosh', 'Allan Houston', 'Tom Gugliotta', 'Michael Cage', 'Jayson Williams', 'Chris Webber', 'Bill Cartwright', 'Kristaps Porzingis', 'Gus Williams', 'Chris Paul', 'Reggie Lewis', 'Joe Barry', 'A.C. Green', 'Roy Hinson', 'Johnny Moore', 'Derrick McKey', 'Hersey Hawkins', 'Vern Fleming', "Amar'e Stoudemire", 'Dirk Nowitzki', 'Derrick Rose', 'Thaddeus Young', 'Otto Porter', 'Armen Gilliam', 'Anfernee Hardaway', 'Detlef Schrempf', 'Elton Brand', 'Kiki Vandeweghe', 'Clarence Weatherspoon', 'Mahmoud Abdul-Rauf', 'James Silas', 'Jeff Ruland', 'Elden Campbell', 'Tim Hardaway', 'Mike Gminski', 'Jalen Rose', 'Damian Lillard', 'Danny Manning', 'Mehmet Okur', 'Alvin Robertson', 'Dale Ellis', 'Clark Kellogg', 'Kyle Lowry', 'Mookie Blaylock', 'Myles Turner', 'Tony Parker', 'Andrew Toney', 'Derek Harper', 'Rashard Lewis', 'Kermit Washington', 'Mark Price', 'Swen Nater', 'Al Jefferson', 'Christian Laettner', 'Ty Lawson', 'Steve Stipanovich', 'Paul Pierce', 'Michael Redd', 'Chandler Parsons', 'Kenyon Martin', 'Jerome Kersey', 'Gene Banks', 'Jeff Malone', 'Scott Skiles', 'Nikola Vucevic', 'Gorgui Dieng', 'Anthony Davis', 'Donyell Marshall', 'Stephen Curry', 'Vince Carter']
#
# ==> Checking which players are Hall of Famer according to DecisionTreeClassifier ...
# --> # of HoF predicted to be HoF =   8 (TP)
# --> # of HoF predicted to be non-HoF =  10 (FN)
# --> # of non-HoF predicted to be HoF =  23 (FP)
# --> # of non-HoF predicted to be non-HoF = 520 (TN)
#
# --> # of HoF predicted to be HoF ['Jack Sikma', 'Patrick Ewing', 'Yao Ming', 'Chris Mullin', 'Scottie Pippen', 'Tim Duncan', 'Kevin Garnett', 'Calvin Murphy']
#
# --> # of HoF predicted to be non-HoF ['Michael Jordan', 'Dave Cowens', 'Gary Payton', 'Drazen Petrovic', 'David Robinson', 'Wes Unseld', 'Larry Bird', 'Tracy McGrady', 'John Stockton', 'Jamaal Wilkes']
#
# --> # of non-HoF predicted to be HoF ['Eddie Jones', 'Chris Bosh', 'Bill Cartwright', 'Kristaps Porzingis', 'John Williamson', 'Joe Barry', 'Hersey Hawkins', 'Derrick Rose', 'Elton Brand', 'Kiki Vandeweghe', 'James Silas', 'Michael Carter-Williams', 'Dale Ellis', 'Clark Kellogg', 'Tony Parker', 'Andrew Toney', 'Al Jefferson', 'Ty Lawson', 'Michael Redd', 'Kenyon Martin', 'Jeff Malone', 'Jusuf Nurkic', 'Anthony Davis']
#
# ==> Checking which players are Hall of Famer according to RandomForestClassifier ...
# --> # of HoF predicted to be HoF =   9 (TP)
# --> # of HoF predicted to be non-HoF =   9 (FN)
# --> # of non-HoF predicted to be HoF =  16 (FP)
# --> # of non-HoF predicted to be non-HoF = 527 (TN)
#
# --> # of HoF predicted to be HoF ['Jack Sikma', 'Patrick Ewing', 'Gary Payton', 'Yao Ming', 'Chris Mullin', 'Tim Duncan', 'Larry Bird', 'Kevin Garnett', 'Tracy McGrady']
#
# --> # of HoF predicted to be non-HoF ['Michael Jordan', 'Dave Cowens', 'Drazen Petrovic', 'Scottie Pippen', 'David Robinson', 'Wes Unseld', 'John Stockton', 'Jamaal Wilkes', 'Calvin Murphy']
#
# --> # of non-HoF predicted to be HoF ['Eddie Jones', 'Chris Bosh', 'Gus Williams', 'Reggie Lewis', "Amar'e Stoudemire", 'Dirk Nowitzki', 'Derrick Rose', 'Anfernee Hardaway', 'Detlef Schrempf', 'Elton Brand', 'Jeff Ruland', 'Myles Turner', 'Mark Price', 'Steve Stipanovich', 'Anthony Davis', 'Vince Carter']
#
# ==> Checking which players are Hall of Famer according to AdaBoostClassifier ...
# --> # of HoF predicted to be HoF =  14 (TP)
# --> # of HoF predicted to be non-HoF =   4 (FN)
# --> # of non-HoF predicted to be HoF =  41 (FP)
# --> # of non-HoF predicted to be non-HoF = 502 (TN)
#
# --> # of HoF predicted to be HoF ['Michael Jordan', 'Jack Sikma', 'Patrick Ewing', 'Gary Payton', 'Yao Ming', 'Chris Mullin', 'Scottie Pippen', 'David Robinson', 'Wes Unseld', 'Tim Duncan', 'Larry Bird', 'Kevin Garnett', 'Tracy McGrady', 'Jamaal Wilkes']
#
# --> # of HoF predicted to be non-HoF ['Dave Cowens', 'Drazen Petrovic', 'John Stockton', 'Calvin Murphy']
#
# --> # of non-HoF predicted to be HoF ['Eddie Jones', 'World B.', 'Mychal Thompson', 'Chris Bosh', 'Chris Webber', 'Bill Cartwright', 'Gus Williams', 'Reggie Lewis', 'Joe Barry', 'Hersey Hawkins', "Amar'e Stoudemire", 'Al Thornton', 'Dirk Nowitzki', 'Derrick Rose', 'Anfernee Hardaway', 'Detlef Schrempf', 'Elton Brand', 'Kiki Vandeweghe', 'James Silas', 'Jeff Ruland', 'Tim Hardaway', 'Michael Carter-Williams', 'Mike Gminski', 'Danny Manning', 'Alvin Robertson', 'Kyle Lowry', 'Myles Turner', 'Tony Parker', 'Rashard Lewis', 'Mark Price', 'Al Jefferson', 'Christian Laettner', 'Ty Lawson', 'Steve Stipanovich', 'Paul Pierce', 'Kenyon Martin', 'Jeff Malone', 'Jusuf Nurkic', 'Anthony Davis', 'Stephen Curry', 'Vince Carter']
#
# ==> Checking which players are Hall of Famer according to GradientBoostingClassifier ...
# --> # of HoF predicted to be HoF =   9 (TP)
# --> # of HoF predicted to be non-HoF =   9 (FN)
# --> # of non-HoF predicted to be HoF =  21 (FP)
# --> # of non-HoF predicted to be non-HoF = 522 (TN)
#
# --> # of HoF predicted to be HoF ['Patrick Ewing', 'Yao Ming', 'Chris Mullin', 'Scottie Pippen', 'David Robinson', 'Tim Duncan', 'Larry Bird', 'Kevin Garnett', 'Tracy McGrady']
#
# --> # of HoF predicted to be non-HoF ['Michael Jordan', 'Jack Sikma', 'Dave Cowens', 'Gary Payton', 'Drazen Petrovic', 'Wes Unseld', 'John Stockton', 'Jamaal Wilkes', 'Calvin Murphy']
#
# --> # of non-HoF predicted to be HoF ['World B.', 'Chris Bosh', 'Gus Williams', 'Reggie Lewis', "Amar'e Stoudemire", 'Dirk Nowitzki', 'Derrick Rose', 'Anfernee Hardaway', 'Detlef Schrempf', 'Elton Brand', 'Kiki Vandeweghe', 'Jeff Ruland', 'Tim Hardaway', 'Danny Manning', 'Myles Turner', 'Tony Parker', 'Mark Price', 'Steve Stipanovich', 'Paul Pierce', 'Anthony Davis', 'Vince Carter']

# %%
X = joined_df.drop(['Player'],axis=1)
X_recent_scaled = X_scaler.transform(X)

# %%
agg_player_list = []

for model in loaded_models:
    player_list = []
    name = type(model).__name__
#     print("==> Checking which players are Hall of Famer according to {} ...".format(name))  
    y_prediction = model.predict(X_recent_scaled)  
    
    y_proba = model.predict_proba(X_recent_scaled)[:,1]
    for i in range(len(X_recent_scaled)):
        player_name = joined_df.iloc[i]['Player']
        player_proba = y_proba[i]
        if y_prediction[i] == 1:          
            if player_proba >= 0.6:
                player_name_and_proba_dict = {'Name':player_name, "Probability":player_proba}
                player_list.append(player_name_and_proba_dict)
            else:
                continue
        else:
            continue
    agg_player_list.append(player_list)

# %%
joined_df.query('Player == "Joakim Noah"')
# Out:
#           Player   MP/G  2P/G   2P%  3P/G  3P%  FT/G   FT%   USG%  ORB/G  ...  \
# 382  Joakim Noah  33.16  4.09  0.49   0.0  0.0  2.53  0.72  16.44   3.66  ...
#
#      STL/G  BLK/G  PTS/G   OWS   DWS    WS  OBPM  DBPM  BPM  VORP
# 382   0.96   1.54  10.72  3.52  4.44  7.96  0.98   2.5  3.5  3.06
#
# [1 rows x 22 columns]

# %%
agg_player_list
# Out:
# [[{'Name': 'Al Horford', 'Probability': 0.6666666666666666},
#   {'Name': 'Al Jefferson', 'Probability': 1.0},
#   {'Name': 'Anthony Davis', 'Probability': 0.6666666666666666},
#   {'Name': 'Brook Lopez', 'Probability': 0.6666666666666666},
#   {'Name': 'Carlos Boozer', 'Probability': 1.0},
#   {'Name': 'Chris Paul', 'Probability': 0.6666666666666666},
#   {'Name': 'David Lee', 'Probability': 1.0},
#   {'Name': 'DeMarcus Cousins', 'Probability': 1.0},
#   {'Name': 'Dwight Howard', 'Probability': 0.6666666666666666},
#   {'Name': 'Dwyane Wade', 'Probability': 1.0},
#   {'Name': 'Greg Monroe', 'Probability': 1.0},
#   {'Name': 'James Harden', 'Probability': 0.6666666666666666},
#   {'Name': 'Kevin Durant', 'Probability': 0.6666666666666666},
#   {'Name': 'Kevin Garnett', 'Probability': 0.6666666666666666},
#   {'Name': 'Nenê Hilário', 'Probability': 1.0},
#   {'Name': 'Pau Gasol', 'Probability': 1.0},
#   {'Name': 'Rudy Gay', 'Probability': 0.6666666666666666},
#   {'Name': 'Russell Westbrook', 'Probability': 1.0},
#   {'Name': 'Thaddeus Young', 'Probability': 0.6666666666666666},
#   {'Name': 'Zach Randolph', 'Probability': 1.0}],
#  [{'Name': 'Anthony Davis', 'Probability': 0.9588214229715727},
#   {'Name': 'Blake Griffin', 'Probability': 0.8670425233829311},
#   {'Name': 'DeMarcus Cousins', 'Probability': 0.76430551194885},
#   {'Name': 'Dwight Howard', 'Probability': 0.968277045030131},
#   {'Name': 'Dwyane Wade', 'Probability': 0.6123197624921396},
#   {'Name': 'Kevin Durant', 'Probability': 0.9726639671773396},
#   {'Name': 'Kevin Love', 'Probability': 0.7169464304128249},
#   {'Name': 'LaMarcus Aldridge', 'Probability': 0.7947444769824112},
#   {'Name': 'LeBron James', 'Probability': 0.9746024934446278},
#   {'Name': 'Marc Gasol', 'Probability': 0.6254200413814295},
#   {'Name': 'Pau Gasol', 'Probability': 0.7834636348345267},
#   {'Name': 'Russell Westbrook', 'Probability': 0.8002360630210152},
#   {'Name': 'Tim Duncan', 'Probability': 0.7071201380496216}],
#  [],
#  [{'Name': 'Dwight Howard', 'Probability': 0.8966429396481652}],
#  [],
#  [{'Name': 'Al Jefferson', 'Probability': 1.0},
#   {'Name': 'Andrew Wiggins', 'Probability': 1.0},
#   {'Name': 'Anthony Davis', 'Probability': 1.0},
#   {'Name': 'Blake Griffin', 'Probability': 1.0},
#   {'Name': 'Brook Lopez', 'Probability': 1.0},
#   {'Name': 'Damian Lillard', 'Probability': 1.0},
#   {'Name': 'Dion Waiters', 'Probability': 1.0},
#   {'Name': 'Dwyane Wade', 'Probability': 1.0},
#   {'Name': 'Kevin Martin', 'Probability': 1.0},
#   {'Name': 'Klay Thompson', 'Probability': 1.0},
#   {'Name': 'LaMarcus Aldridge', 'Probability': 1.0},
#   {'Name': 'Michael Carter-Williams', 'Probability': 1.0},
#   {'Name': 'Tim Duncan', 'Probability': 1.0},
#   {'Name': 'Ty Lawson', 'Probability': 1.0},
#   {'Name': 'Zach Randolph', 'Probability': 1.0}],
#  [{'Name': 'Blake Griffin', 'Probability': 0.63},
#   {'Name': 'Dwyane Wade', 'Probability': 0.615}],
#  [],
#  [{'Name': 'Anthony Davis', 'Probability': 0.8684517830531538},
#   {'Name': 'Blake Griffin', 'Probability': 0.9852294196046762},
#   {'Name': 'Chris Bosh', 'Probability': 0.8589897722969471},
#   {'Name': 'Damian Lillard', 'Probability': 0.7782364932404637},
#   {'Name': 'David West', 'Probability': 0.8332705487825165},
#   {'Name': 'DeMarcus Cousins', 'Probability': 0.6967316775919379},
#   {'Name': 'Dwyane Wade', 'Probability': 0.9721435124181534},
#   {'Name': 'LaMarcus Aldridge', 'Probability': 0.9800677093295486},
#   {'Name': 'Marc Gasol', 'Probability': 0.9039638196150368},
#   {'Name': 'Mike Conley', 'Probability': 0.7569475469073529},
#   {'Name': 'Paul Millsap', 'Probability': 0.7825152616250172},
#   {'Name': 'Paul Pierce', 'Probability': 0.7449864106117814},
#   {'Name': 'Tim Duncan', 'Probability': 0.8779553598912139},
#   {'Name': 'Tony Parker', 'Probability': 0.6310194744830172}]]
